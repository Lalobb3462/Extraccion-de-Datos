# %% [markdown]
# **Actividad 2.3 (Evaluación)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Carga de archivos**

# %%
#En este paso, nosotros cargamos el archivo como tipo csv
lisboa= pd.read_csv("listings.csv", index_col=None)
lisboa
# Out:
#                         id                                       listing_url  \
# 0                   208683               https://www.airbnb.com/rooms/208683
# 1                   211614               https://www.airbnb.com/rooms/211614
# 2                   211616               https://www.airbnb.com/rooms/211616
# 3                   214729               https://www.airbnb.com/rooms/214729
# 4                   217281               https://www.airbnb.com/rooms/217281
# ...                    ...                                               ...
# 24199  1243403799584587485  https://www.airbnb.com/rooms/1243403799584587485
# 24200  1243421531996967673  https://www.airbnb.com/rooms/1243421531996967673
# 24201  1243488183394801906  https://www.airbnb.com/rooms/1243488183394801906
# 24202  1243509538559076353  https://www.airbnb.com/rooms/1243509538559076353
# 24203  1243552535635447045  https://www.airbnb.com/rooms/1243552535635447045
#
# ...

# %% [markdown]
# **a) Los registros de 5 "host_name" diferentes**

# %%
#En este paso, creamos una tabla que muestre solo los alojamientos administrados por las personas que tienen alguno de los siguientes nombres
nombres= lisboa[(lisboa["host_name"]=="Joel")|(lisboa["host_name"]=="Augusto")|(lisboa["host_name"]=="Victor")|(lisboa["host_name"]=="Ines")|(lisboa["host_name"]=="Mateus")]
nombres
#nombres.to_csv("incisoa.csv")
# Out:
#                         id                                       listing_url  \
# 29                  262251               https://www.airbnb.com/rooms/262251
# 31                  263399               https://www.airbnb.com/rooms/263399
# 33                   76132                https://www.airbnb.com/rooms/76132
# 46                  279549               https://www.airbnb.com/rooms/279549
# 47                  281407               https://www.airbnb.com/rooms/281407
# ...                    ...                                               ...
# 23449  1211420979001434884  https://www.airbnb.com/rooms/1211420979001434884
# 24012  1237610964738531964  https://www.airbnb.com/rooms/1237610964738531964
# 24059  1238476139444019919  https://www.airbnb.com/rooms/1238476139444019919
# 24065  1238926224664768919  https://www.airbnb.com/rooms/1238926224664768919
# 24175  1242684479776899452  https://www.airbnb.com/rooms/1242684479776899452
#
# ...

# %% [markdown]
# **b) Los registros de los host que se hayan unido a Airbnb "antes del año 2019"**

# %%
#Aquí filtramos los datos de aquellos anfitriones que lo sond esde antes de 2019.
fecha_inicio= lisboa[lisboa["host_since"] < "2019-01-01"]
fecha_inicio
#fecha_inicio.to_csv("incisob.csv")

# %% [markdown]
# **c) Los registros de los host que responden "a más tardar un día"**

# %%
#Aquí se filtran los datos de aquellos anfitriones con un tiempo de respuesta dentro de un día.
responder1= lisboa[lisboa["host_response_time"]=="within a day"]
responder1
#responder1.to_csv("incisoc.csv")

# %% [markdown]
# **d) Los registros que tengan al menos "5 accommodates"**

# %%
#Aquí se muestran aquellos anfitriones que tienen 5 o más "accommodates" en su alojamiento.
comodidades= lisboa[lisboa["accommodates"] >= 5]
comodidades
#comodidades.to_csv("incisod.csv")

# %% [markdown]
# **e) "Los registros de los tipos de cuartos: "Entire room" y "Private room"**

# %%
#Aquí se muestran aquellos alojamientos que son de tipo habitación privada o de tipo casa o apartamento completo.
tipo_cuarto= lisboa[(lisboa["room_type"] =="Private room") | (lisboa["room_type"] =="Entire home/apt")]
tipo_cuarto
#tipo_cuarto.to_csv("incisoe.csv")
# Out:
#                         id                                       listing_url  \
# 0                   208683               https://www.airbnb.com/rooms/208683
# 1                   211614               https://www.airbnb.com/rooms/211614
# 2                   211616               https://www.airbnb.com/rooms/211616
# 3                   214729               https://www.airbnb.com/rooms/214729
# 4                   217281               https://www.airbnb.com/rooms/217281
# ...                    ...                                               ...
# 24199  1243403799584587485  https://www.airbnb.com/rooms/1243403799584587485
# 24200  1243421531996967673  https://www.airbnb.com/rooms/1243421531996967673
# 24201  1243488183394801906  https://www.airbnb.com/rooms/1243488183394801906
# 24202  1243509538559076353  https://www.airbnb.com/rooms/1243509538559076353
# 24203  1243552535635447045  https://www.airbnb.com/rooms/1243552535635447045
#
# ...

# %% [markdown]
# **f) Los registros que "a lo mucho cuenten con 4 camas"**

# %%
#Aquí se filtran los datos de aquellos alojamientos con 4 o menos camas.
camas= lisboa[lisboa["beds"] <= 4]
camas
#camas.to_csv("incisof.csv")
# Out:
#                         id                                       listing_url  \
# 0                   208683               https://www.airbnb.com/rooms/208683
# 2                   211616               https://www.airbnb.com/rooms/211616
# 3                   214729               https://www.airbnb.com/rooms/214729
# 4                   217281               https://www.airbnb.com/rooms/217281
# 6                   220359               https://www.airbnb.com/rooms/220359
# ...                    ...                                               ...
# 24199  1243403799584587485  https://www.airbnb.com/rooms/1243403799584587485
# 24200  1243421531996967673  https://www.airbnb.com/rooms/1243421531996967673
# 24201  1243488183394801906  https://www.airbnb.com/rooms/1243488183394801906
# 24202  1243509538559076353  https://www.airbnb.com/rooms/1243509538559076353
# 24203  1243552535635447045  https://www.airbnb.com/rooms/1243552535635447045
#
# ...

# %% [markdown]
# **g) Los registros que "tengan 1 baño o que sean superhost" pero con la condición de que "todos sean instant_bookable"**

# %%
#Aquí filtre dos datos de manera separada: primero aquellos alojamientos que te permiten
#reservar al instante, y después aquellos que cumplieran una de las dos condiciones propuestas,
#que tengan un baño o que el anfitrión sea un superhost.
instante= lisboa[lisboa["instant_bookable"]=="t"]
condiciones = instante[(instante["bathrooms"]==1) | (instante["host_is_superhost"]=="t")]
condiciones
#condiciones.to_csv("incisog.csv")
# Out:
#                         id                                       listing_url  \
# 13                    6499                 https://www.airbnb.com/rooms/6499
# 14                   25659                https://www.airbnb.com/rooms/25659
# 15                   29396                https://www.airbnb.com/rooms/29396
# 23                  250491               https://www.airbnb.com/rooms/250491
# 24                  250526               https://www.airbnb.com/rooms/250526
# ...                    ...                                               ...
# 24190  1243243461119280975  https://www.airbnb.com/rooms/1243243461119280975
# 24193  1243278129174932175  https://www.airbnb.com/rooms/1243278129174932175
# 24197  1243349316679646119  https://www.airbnb.com/rooms/1243349316679646119
# 24199  1243403799584587485  https://www.airbnb.com/rooms/1243403799584587485
# 24202  1243509538559076353  https://www.airbnb.com/rooms/1243509538559076353
#
# ...

# %% [markdown]
# **h) Los registros cuyo "review_scores_cleanliness sea menor de 3 y review_scores_rating sea mayor de 3**

# %%
#Aquí se filtraron aquellos alojamientos que cumplan ambas condiciones, puntajes menores a 3 en "review_scores_cleanliness" y mayor a 3 en "review_scores_rating"
limpiezarating= lisboa[(lisboa["review_scores_cleanliness"]<3) & (lisboa["review_scores_rating"]>3)]
limpiezarating
#limpiezarating.to_csv("incisoh.csv")
# Out:
#                         id                                       listing_url  \
# 843                2945967              https://www.airbnb.com/rooms/2945967
# 11176             46210221             https://www.airbnb.com/rooms/46210221
# 11861             50478626             https://www.airbnb.com/rooms/50478626
# 13564   610004567923045967   https://www.airbnb.com/rooms/610004567923045967
# 13917   640511384308330180   https://www.airbnb.com/rooms/640511384308330180
# 14433   678905534844203496   https://www.airbnb.com/rooms/678905534844203496
# 14519   682040754307724357   https://www.airbnb.com/rooms/682040754307724357
# 15803   817160487267643334   https://www.airbnb.com/rooms/817160487267643334
# 17481   918681782821612269   https://www.airbnb.com/rooms/918681782821612269
# 17510   920199212849432644   https://www.airbnb.com/rooms/920199212849432644
# 17680   925371627989365227   https://www.airbnb.com/rooms/925371627989365227
# ...
