# %% [markdown]
# **Actividad 2.1 (Extracción de datos)**
# **Eduardo Ballinas Ballinas**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Lectura de los datos**

# %%
dp=pd.read_excel("Detalle precios y productos fabricados 2022.xlsx")
dp
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %% [markdown]
# **1. Filtro por objeto**

# %%
objeto=dp[(dp["NOMBRE_CLIENTE"] == "VINILOS")]
objeto
# Out:
#      CVE_DOC  FECHA_DOC     NOMBRE_VENDEDOR NOMBRE_CLIENTE  CANT CVE_ART  \
# 80    F37180 2022-01-24      ALFREDO CANELA        VINILOS    10  TP0004
# 505   F37980 2022-04-26      ALFREDO CANELA        VINILOS    10  TP0003
# 984   F38967 2022-09-02      ALFREDO CANELA        VINILOS    10  TP0004
# 1019  F39029 2022-09-12  AARON NUÑO CORDOVA        VINILOS    10  TP0004
#
#                                        DESCR  PRECIO_UNITARIO  COSTO_UNITARIO  \
# 80    TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 2.5 MT            272.0           77.13
# 505     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 2 MT            250.0           72.37
# 984   TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 2.5 MT            386.0           84.41
# 1019  TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 2.5 MT            386.0           77.13
#
#       COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  \
# 80                       77.13            2720.0                 771.29
# ...

# %% [markdown]
# **2. Filtro por filas**

# %%
filas=dp.iloc[2:6,:]
filas
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN       OMAR RODRIGUEZ GOMEZ
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ         PÚBLICO EN GENERAL
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ         PÚBLICO EN GENERAL
#
#    CANT  CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 2     7   TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
# 3     1   TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00
# 4     2  BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41
# 5     2  BP00243    BAN P INOX 55MMX235MM 450W 127V T/TOR           237.07
#
#    COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 2          177.68                    177.68           3861.29
# 3           38.96                     38.96            140.00
# ...

# %% [markdown]
# **3. Filtro por columnas**

# %%
columnas=dp.iloc[:,0:4]
columnas
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE
# 0               PÚBLICO EN GENERAL
# 1     JUAN ANTONIO RESENDIZ UGALDE
# 2        ANA BARBARA CRUZ PALACIOS
# 3             OMAR RODRIGUEZ GOMEZ
# 4               PÚBLICO EN GENERAL
# ...                            ...
# 1421     LUIS ENRIQUE PATIÑO PEREZ
# 1422     LUIS ENRIQUE PATIÑO PEREZ
# ...

# %% [markdown]
# **4. Filtro de filas por columnas**

# %%
dp1=pd.read_excel("Detalle precios y productos fabricados 2022.xlsx",index_col="CANT")
dp1=dp1.loc[[1,2],["NOMBRE_CLIENTE", "PRECIO_UNITARIO", "COSTO_UNITARIO"]]
dp1
# Out:
#                            NOMBRE_CLIENTE  PRECIO_UNITARIO  COSTO_UNITARIO
# CANT
# 1                      PÚBLICO EN GENERAL           434.48           52.80
# 1            JUAN ANTONIO RESENDIZ UGALDE          1264.05          327.18
# 1                    OMAR RODRIGUEZ GOMEZ           140.00           38.96
# 1     AIRBUS HELICOPTERS MEXICO QUERETARO         14000.00         5323.76
# 1                      FIDEICOMISO F/1596          1615.00          517.89
# ...                                   ...              ...             ...
# 2                      PÚBLICO EN GENERAL           732.00            0.00
# 2                         TRILOGIQ-MEXICO           925.82           65.31
# 2                         TRILOGIQ-MEXICO          1910.50          286.13
# 2                         TRILOGIQ-MEXICO          2020.42          421.91
# 2                         TRILOGIQ-MEXICO          1177.07          477.16
#
# [831 rows x 3 columns]

# %% [markdown]
# **5. Filtro por cabecera**

# %%
cabecera=dp.head(10)
cabecera
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6  F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7  F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 8  F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9  F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
#
#                         NOMBRE_CLIENTE  CANT   CVE_ART  \
# 0                   PÚBLICO EN GENERAL     1  TUE00244
# 1         JUAN ANTONIO RESENDIZ UGALDE     1  TUA00028
# 2            ANA BARBARA CRUZ PALACIOS     7    TP0007
# 3                 OMAR RODRIGUEZ GOMEZ     1    TP0001
# 4                   PÚBLICO EN GENERAL     2   BP00242
# 5                   PÚBLICO EN GENERAL     2   BP00243
# ...

# %% [markdown]
# **6. Filtro por cola**

# %%
cola=dp.tail(10)
cola
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ                     TORJJS
# 1417  F39833 2022-12-23         AARON NUÑO CORDOVA            TRILOGIQ-MEXICO
# 1418  F39833 2022-12-23         AARON NUÑO CORDOVA            TRILOGIQ-MEXICO
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA            TRILOGIQ-MEXICO
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA            TRILOGIQ-MEXICO
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ       SEVEN DAYS ALL SPORT
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ        REVUELTA MONTECARLO
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA             CPEG SOLUTIONS
#
#       CANT       CVE_ART                                     DESCR  \
# ...

# %% [markdown]
# **7. Filtro por comparación**

# %%
comparacion=dp[dp["PRECIO_UNITARIO"]>20000]
comparacion
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 419   F37817 2022-03-31             ALFREDO CANELA
# 479   F37933 2022-04-20  LETICIA RAMIREZ HERNANDEZ
# 672   F38352 2022-06-10             ALFREDO CANELA
# 842   F38648 2022-07-22  LETICIA RAMIREZ HERNANDEZ
# 931   F38850 2022-08-18  LETICIA RAMIREZ HERNANDEZ
# 1046  F39088 2022-09-20  LETICIA RAMIREZ HERNANDEZ
# 1288  F39576 2022-11-15             ALFREDO CANELA
#
#                                   NOMBRE_CLIENTE  CANT   CVE_ART  \
# 419   FABRICACION Y MONTAJE DE EQUIPO INDUSTRIAL     1  GAB00014
# 479                  JUAN CARLOS HERNANDEZ PEREZ     1  TUE00172
# 672                           FLEX-N-GATE MEXICO     1   RP00203
# 842                  JUAN CARLOS HERNANDEZ PEREZ     1  TUE00172
# 931                  JUAN CARLOS HERNANDEZ PEREZ     1  TUE00172
# 1046                      EDGAR GARCIA HERNANDEZ     1  TUE00378
# 1288            CARCOUSTICS INDUSTRIAL DE MEXICO     1   EE00022
#
# ...

# %% [markdown]
# **8. Filtro Y (Conjunción)**

# %%
conjuncion=dp[(dp["NOMBRE_VENDEDOR"]=="LETICIA RAMIREZ HERNANDEZ") & (dp["NOMBRE_CLIENTE"]=="PÚBLICO EN GENERAL") & (dp["SUBTOTAL_PARTIDA"]>4000)]
conjuncion
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR      NOMBRE_CLIENTE  CANT  \
# 530   F38043 2022-04-29  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     2
# 536   F38058 2022-05-02  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL    10
# 739   F38474 2022-06-28  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     9
# 979   F38957 2022-08-31  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     4
# 999   F39004 2022-09-07  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     8
# 1035  F39065 2022-09-14  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     1
# 1241  F39471 2022-11-01  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     6
# 1376  F39754 2022-12-13  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     4
#
#            CVE_ART                                     DESCR  PRECIO_UNITARIO  \
# 530       TUE00034  TUB INOX7 /16x115CMS CLIP15KW220V PLACA"          2497.00
# 536   CS38C1008A00   CAS INOX 3/8"ØX1 1/2" 80W 127V EXT.30CM           488.62
# ...

# %% [markdown]
# **9. Filtro O (Disyunción)**

# %%
disyuncion=dp[(dp["CANT"]>15) | (dp["PRECIO_UNITARIO"]>10000)]
disyuncion
# Out:
#      CVE_DOC  FECHA_DOC           NOMBRE_VENDEDOR  \
# 6     F37044 2022-01-05  DIEGO ARMANDO LEON DURAN
# 29    F37078 2022-01-07            ALFREDO CANELA
# 31    F37086 2022-01-10            ALFREDO CANELA
# 38    F37098 2022-01-12  DIEGO ARMANDO LEON DURAN
# 40    F37102 2022-01-12            ALFREDO CANELA
# ...      ...        ...                       ...
# 1365  F39731 2022-12-08            ALFREDO CANELA
# 1393  F39788 2022-12-19            ALFREDO CANELA
# 1397  F39794 2022-12-20        AARON NUÑO CORDOVA
# 1403  F39810 2022-12-22            ALFREDO CANELA
# 1412  F39824 2022-12-23            ALFREDO CANELA
#
#                                     NOMBRE_CLIENTE  CANT    CVE_ART  \
# 6              AIRBUS HELICOPTERS MEXICO QUERETARO     1    RP00165
# 29                           CLAVOS NACIONALES C.N    30  BOBINA001
# 31                           CLAVOS NACIONALES C.N    30  BOBINA001
# 38                                       REDYPLAST    40   CBS00045
# ...

# %% [markdown]
# **10. Filtro Not (Negación)**

# %%
negacion=dp[~(dp["COSTO_UNITARIO"]==0)]
negacion
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...
